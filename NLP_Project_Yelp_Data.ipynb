# %% [markdown]
# <a href="https://colab.research.google.com/github/NourAJ20/NourAJ20/blob/main/NLP_Project_Yelp_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Read the yelp.csv file and set it as a dataframe called yelp
yelp = pd.read_csv('yelp.csv')

# %%
yelp.head(5)
# Out:
#               business_id        date               review_id  stars  \
# 0  9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1  ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2  6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3  _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4  6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
#
#                                                 text    type  \
# 0  My wife took me here on my birthday for breakf...  review
# 1  I have no idea why some people give bad review...  review
# 2  love the gyro plate. Rice is so good and I als...  review
# 3  Rosie, Dakota, and I LOVE Chaparral Dog Park!!...  review
# 4  General Manager Scott Petello is a good egg!!!...  review
#
#                   user_id  cool  useful  funny
# 0  rLtl8ZkDX5vH5nAx9C3q5Q     2       5      0
# 1  0a2KyEL0d3Yb1V6aivbIuQ     0       0      0
# ...

# %%
yelp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   business_id  10000 non-null  object
#  1   date         10000 non-null  object
#  2   review_id    10000 non-null  object
#  3   stars        10000 non-null  int64
#  4   text         10000 non-null  object
#  5   type         10000 non-null  object
#  6   user_id      10000 non-null  object
#  7   cool         10000 non-null  int64
#  8   useful       10000 non-null  int64
#  9   funny        10000 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 781.4+ KB

# %%
yelp.describe()
# Out:
#               stars          cool        useful         funny
# count  10000.000000  10000.000000  10000.000000  10000.000000
# mean       3.777500      0.876800      1.409300      0.701300
# std        1.214636      2.067861      2.336647      1.907942
# min        1.000000      0.000000      0.000000      0.000000
# 25%        3.000000      0.000000      0.000000      0.000000
# 50%        4.000000      0.000000      1.000000      0.000000
# 75%        5.000000      1.000000      2.000000      1.000000
# max        5.000000     77.000000     76.000000     57.000000

# %%
# Create a new column called "text lenght" which is the number of words in the text columnn.

yelp['text lenght'] = yelp['text'].apply(len)

# %%
yelp
# Out:
#                  business_id        date               review_id  stars  \
# 0     9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1     ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2     6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3     _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4     6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
# ...                      ...         ...                     ...    ...
# 9995  VY_tvNUCCXGXQeSvJl757Q  2012-07-28  Ubyfp2RSDYW0g7Mbr8N3iA      3
# 9996  EKzMHI1tip8rC1-ZAy64yg  2012-01-18  2XyIOQKbVFb6uXQdJ0RzlQ      4
# 9997  53YGfwmbW73JhFiemNeyzQ  2010-11-16  jyznYkIbpqVmlsZxSDSypA      4
# 9998  9SKdOoDHcFoxK5ZtsgHJoA  2012-12-02  5UKq9WQE1qQbJ0DJbc-B6Q      2
# 9999  pF7uRzygyZsltbmVpjIyvw  2010-10-16  vWSmOhg2ID1MNZHaWapGbA      5
#
#                                                    text    type  \
# ...

# %%
# Now start some exploratory data analysis

# Set style for seaborn

sns.set_style('white')

# %% [markdown]
# Next:
#
# Use FacetGrid from the seaborn library to create a grid of 5 histograms of text lenght based off of the star ratings.

# %%
g = sns.FacetGrid(yelp, col='stars')
g.map(plt.hist, 'text lenght', bins = 50)

# %% [markdown]
# Create a boxplot of text lenght for each catagory

# %%
sns.boxplot(x = 'stars', y = 'text lenght', data=yelp, palette = 'rainbow')
# Out:
# <ipython-input-11-4c7fe6acab41>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'stars', y = 'text lenght', data=yelp, palette = 'rainbow')
# <Axes: xlabel='stars', ylabel='text lenght'>

# %% [markdown]
# Create a countplot of the number of occurrences for each type of star rating

# %%
sns.countplot(x = 'stars', data = yelp, palette = 'rainbow')
# Out:
# <ipython-input-12-f5632b4863dd>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'stars', data = yelp, palette = 'rainbow')
# <Axes: xlabel='stars', ylabel='count'>

# %% [markdown]
# Use groupby to get the mean values of the numerical columns, you should be able to create this dataframe with the operations:

# %%
# Calculate the mean of only the numeric columns
stars = yelp.groupby('stars').mean(numeric_only=True)
stars

# numeric_only = True; this is used for the numeric columns only
# Out:
#            cool    useful     funny  text lenght
# stars
# 1      0.576769  1.604806  1.056075   826.515354
# 2      0.719525  1.563107  0.875944   842.256742
# 3      0.788501  1.306639  0.694730   758.498289
# 4      0.954623  1.395916  0.670448   712.923142
# 5      0.944261  1.381780  0.608631   624.999101

# %% [markdown]
# use the corr() method on that groupby dataframe

# %%
#Correlation method on the stars^ data

stars.corr()
# Out:
#                  cool    useful     funny  text lenght
# cool         1.000000 -0.743329 -0.944939    -0.857664
# useful      -0.743329  1.000000  0.894506     0.699881
# funny       -0.944939  0.894506  1.000000     0.843461
# text lenght -0.857664  0.699881  0.843461     1.000000

# %% [markdown]
# Use seaborn to create a heatmap off of the information above.

# %%
sns.heatmap(stars.corr(), cmap = 'coolwarm', annot = True)
# Out:
# <Axes: >

# %% [markdown]
# NLP Classification Task
#
# Go ahead and only grab reviews that were either 1 stars or 5 stars
#
# Create a dataframe called yelp_class that only contains the columns of yelp dataframe but for only the 1 or 5 star reviews.

# %%
yelp_class = yelp[yelp.stars.isin([1,5])]

#another way
#yelp_class = yelp[(yelp['stars']==1 | (yelp['stars']==5)]

# %%
yelp_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4086 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   business_id  4086 non-null   object
#  1   date         4086 non-null   object
#  2   review_id    4086 non-null   object
#  3   stars        4086 non-null   int64
#  4   text         4086 non-null   object
#  5   type         4086 non-null   object
#  6   user_id      4086 non-null   object
#  7   cool         4086 non-null   int64
#  8   useful       4086 non-null   int64
#  9   funny        4086 non-null   int64
#  10  text lenght  4086 non-null   int64
# dtypes: int64(5), object(6)
# memory usage: 383.1+ KB

# %% [markdown]
# Create two objects X and y.
#
# X will be the 'text' column of yelp_class and y will be the 'stars' column of yelp_class. (Your features and target/labels)

# %%
X = yelp_class['text']
y = yelp_class['stars']

# %% [markdown]
# Import CountVectorizer and create a CountVectorizer object.

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()

# %% [markdown]
# Use the fit_transform method on the CountVectorizer object and pass in X (the 'text' column). Save this result by overwriting X.

# %%
X = cv.fit_transform(X)

# %% [markdown]
# Train Test Split
#
# Now, let split our data.
#
# Use train_test_split to split up the data into X_train, X_test, y_train, y_test.
#
# Use test_size=0.3
# random state = 101

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 101)

# %% [markdown]
# Train a model
#
# Import MultinomialNM and create an instance of the estimator and call it nb

# %%
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()

# %% [markdown]
# Now fit nb using the training data

# %%
nb.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %% [markdown]
# Predictions and Evaluations
#
# Time to see how the model did.
#
# Use the **predict method** off of nb to predict lables from X_test

# %%
predictions = nb.predict(X_test)

# %% [markdown]
# Create a confusion Matrix and classification report using these predictions and y_test

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(confusion_matrix(y_test, predictions))
print('\n')
print(classification_report(y_test, predictions))

# Confusion Matrix and Classification report
# Out:
# [[159  69]
#  [ 22 976]]
#
#
#               precision    recall  f1-score   support
#
#            1       0.88      0.70      0.78       228
#            5       0.93      0.98      0.96       998
#
#     accuracy                           0.93      1226
#    macro avg       0.91      0.84      0.87      1226
# weighted avg       0.92      0.93      0.92      1226

# %% [markdown]
# What is a confusion matrix?
#
# A confusion matrix is a performance evaluation metric that is used to evaluate the accuracy of a classification model. It's a table with four different combinations of predicted and actual values.
#
#
# **True Positive (TP)**: Correctly predicted positive cases.
# **True Negative (TN)**: Correctly predicted negative cases.
# **False Positive (FP)**: Incorrectly predicted as positive (Type I error).
# **False Negative (FN)**: Incorrectly predicted as negative (Type II error).

# %% [markdown]
# What the confusion matrix score means.
#
# True Positives (TP) = 976: The model correctly predicted 976 positive cases.
# True Negatives (TN) = 159: The model correctly predicted 159 negative cases.
# False Positives (FP) = 69: The model incorrectly predicted 69 cases as positive when they were actually negative.
# False Negatives (FN) = 22: The model incorrectly predicted 22 cases as negative when they were actually positive.

# %% [markdown]
# **Classification Report**
#
# A classification report is a performance evaluation metric that provides a summary of the precision, recall, F1-score, and support for each class in a classification problem. It's a convenient way to assess the performance of a multi-class classification model.
#
# **Based on the provided classification report:**
#
# **Class 1:**
# Precision: 0.88 (88% of predicted positive cases were actually positive)
# Recall: 0.70 (70% of actual positive cases were correctly predicted)
# F1-score: 0.78 (balance between precision and recall)
# Support: 228 (number of instances of class 1)
# **Class 5:**
# Precision: 0.93 (93% of predicted positive cases were actually positive)
# Recall: 0.98 (98% of actual positive cases were correctly predicted)
# F1-score: 0.96 (balance between precision and recall)
# Support: 998 (number of instances of class 5)
# Overall Accuracy: 0.93 (93% of all instances were correctly classified).

# %% [markdown]
# Now that we are done with that, lets see what happens if we try to include TF-IDF to this process using a pipeline.

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline

# %% [markdown]
# Now create a pipeline with the following steps:
#
# **CountVectorizer()**
#
# **TfidfTransformer()**
#
# **MultinomialNB()**

# %%
pipe = Pipeline([('bow', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', MultinomialNB())])

# %% [markdown]
# Time to use the pipeline.
#
# Remember, this has all your pre-process steps in it already. This means we will need to re-split the original data (Remember that we overwrote X as the CountVectorized version.)
#
# We need the text from that version.

# %% [markdown]
# ***Train Test Split ***
#
# Redo the train test split on the yelp_class object

# %%
X = yelp_class['text']
y = yelp_class['stars']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 101)

# %% [markdown]
# Now fit the pipeline to the training data.
#
# Remember you can't use the same training data as before because that has already been vectorized. We need to pass in just the text and labels.

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('bow', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('model', MultinomialNB())])

# %% [markdown]
# **Predictions and Evaluation **
#
# Now use the pipeline to predict from the X_test and create a classification report and confusion matrix. You should notice **strange results **

# %%
predictions = pipe.predict(X_test)

# %%
print(confusion_matrix(y_test, predictions))
print('\n')
print(classification_report(y_test, predictions))
# Out:
# [[  0 228]
#  [  0 998]]
#
#
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00       228
#            5       0.81      1.00      0.90       998
#
#     accuracy                           0.81      1226
#    macro avg       0.41      0.50      0.45      1226
# weighted avg       0.66      0.81      0.73      1226
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# We will end the project here. Continue exploring more if you would like.
#
# It looks like the Tf-idf actually made things worse.
#
# Some tips for other things to try;
# Go back to the pipeline steps and see if creating a cunstom analyzer like we did in the lecture helps. (note: it won't)
#
# Or recreate the pipeline with judt the CountVectorizer() and NaiveBayes.
#
# Does changes the ML model at the end to another classifier help?
#
# To be continued....
