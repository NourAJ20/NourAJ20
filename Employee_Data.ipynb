# %% [markdown]
# <a href="https://colab.research.google.com/github/NourAJ20/NourAJ20/blob/main/Employee_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#Read in the employee data csv file and set it to a DataFrame called emp

emp = pd.read_csv('employee_data.csv')

# %%
emp.head(10)
# Out:
#    EmpID FirstName  LastName  StartDate   ExitDate                    Title  \
# 0   3427     Uriah   Bridges  20-Sep-19        NaN  Production Technician I
# 1   3428     Paula     Small  11-Feb-23        NaN  Production Technician I
# 2   3429    Edward      Buck  10-Dec-18        NaN       Area Sales Manager
# 3   3430   Michael   Riordan  21-Jun-21        NaN       Area Sales Manager
# 4   3431   Jasmine     Onque  29-Jun-19        NaN       Area Sales Manager
# 5   3432     Maruk    Fraval  17-Jan-20        NaN       Area Sales Manager
# 6   3433     Latia     Costa  06-Apr-22  03-Jul-23       Area Sales Manager
# 7   3434  Sharlene     Terry  06-Nov-20  29-Jan-23       Area Sales Manager
# 8   3435       Jac  McKinzie  18-Aug-18        NaN       Area Sales Manager
# 9   3436    Joseph   Martins  21-Jan-22  29-Jun-23       Area Sales Manager
#
#         Supervisor                        ADEmail BusinessUnit EmployeeStatus  \
# ...

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   EmpID                       3000 non-null   int64
#  1   FirstName                   3000 non-null   object
#  2   LastName                    3000 non-null   object
#  3   StartDate                   3000 non-null   object
#  4   ExitDate                    1533 non-null   object
#  5   Title                       3000 non-null   object
#  6   Supervisor                  3000 non-null   object
#  7   ADEmail                     3000 non-null   object
#  8   BusinessUnit                3000 non-null   object
#  9   EmployeeStatus              3000 non-null   object
#  10  EmployeeType                3000 non-null   object
#  11  PayZone                     3000 non-null   object
#  12  EmployeeClassificationType  3000 non-null   object
# ...

# %%
emp.columns
# Out:
# Index(['EmpID', 'FirstName', 'LastName', 'StartDate', 'ExitDate', 'Title',
#        'Supervisor', 'ADEmail', 'BusinessUnit', 'EmployeeStatus',
#        'EmployeeType', 'PayZone', 'EmployeeClassificationType',
#        'TerminationType', 'TerminationDescription', 'DepartmentType',
#        'Division', 'DOB', 'State', 'JobFunctionDescription', 'GenderCode',
#        'LocationCode', 'RaceDesc', 'MaritalDesc', 'Performance Score',
#        'Current Employee Rating'],
#       dtype='object')

# %%
len(emp.index)
# Out:
# 3000

# %%
emp['JobFunctionDescription']=='Engineer'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996     True
# 2997    False
# 2998    False
# 2999    False
# Name: JobFunctionDescription, Length: 3000, dtype: bool

# %%
emp[emp['JobFunctionDescription'] == 'Engineer']
# Out:
#       EmpID FirstName    LastName  StartDate   ExitDate  \
# 7      3434  Sharlene       Terry  06-Nov-20  29-Jan-23
# 9      3436    Joseph     Martins  21-Jan-22  29-Jun-23
# 26     3453   Bridger      Carter  13-Oct-22        NaN
# 40     3467     Celia      Curtis  06-May-20        NaN
# 49     3476   Charlie        Koch  12-Jun-23  06-Jul-23
# ...     ...       ...         ...        ...        ...
# 2912   3339    Alyson     Hickman  22-Aug-21        NaN
# 2963   3390    Lizeth   Middleton  21-Oct-22  05-Jan-23
# 2975   3402    Nevaeh    Mcmillan  03-Mar-21  12-Apr-22
# 2978   3405    Selina   Jefferson  13-Jan-20  21-Oct-22
# 2996   3423    Adyson  Strickland  28-Dec-20        NaN
#
#                          Title         Supervisor  \
# 7           Area Sales Manager      Tracy Marquez
# 9           Area Sales Manager     George Jenkins
# 26          Area Sales Manager   Elizabeth Taylor
# 40          Area Sales Manager   Michael Odonnell
# ...

# %%
emp[emp['JobFunctionDescription'] == 'Engineer'].count()
# Out:
# EmpID                         313
# FirstName                     313
# LastName                      313
# StartDate                     313
# ExitDate                      164
# Title                         313
# Supervisor                    313
# ADEmail                       313
# BusinessUnit                  313
# EmployeeStatus                313
# EmployeeType                  313
# PayZone                       313
# EmployeeClassificationType    313
# TerminationType               313
# TerminationDescription        164
# DepartmentType                313
# Division                      313
# DOB                           313
# State                         313
# JobFunctionDescription        313
# GenderCode                    313
# LocationCode                  313
# RaceDesc                      313
# MaritalDesc                   313
# Performance Score             313
# Current Employee Rating       313
# dtype: int64

# %%
emp[emp['JobFunctionDescription'] == 'Engineer']['JobFunctionDescription'].count()

# 313 empoyees are within Engineering
# Out:
# 313

# %%
emp['EmpID']== 3339
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: EmpID, Length: 3000, dtype: bool

# %%
emp[emp['EmpID'] == 3339]['FirstName']
# Out:
# 2912    Alyson
# Name: FirstName, dtype: object

# %%
emp['BusinessUnit']== 'PL'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Name: BusinessUnit, Length: 3000, dtype: bool

# %%
emp[emp['BusinessUnit']== 'PL']['FirstName']
# Out:
# 2         Edward
# 18          Reid
# 30        Milton
# 42        Ryland
# 53      Jerimiah
#           ...
# 2949       Maren
# 2961        Zoie
# 2971       Kyler
# 2982     Brenton
# 2994     Brenden
# Name: FirstName, Length: 301, dtype: object

# %%
emp[emp['BusinessUnit']== 'PL']['BusinessUnit'].count()
# Out:
# 301

# %%
emp[emp['EmployeeStatus']== 'Active']['EmployeeStatus'].count()

# So many are active, great!
# Out:
# 2458

# %%
emp[emp['Current Employee Rating'] == 5]['Current Employee Rating'].count()
# Out:
# 270

# %%
race_counts = emp['RaceDesc'].value_counts()

# %%
race_list = ['{} | {}'.format(race, count) for race, count in race_counts.items()]

# %%
print(race_list)
# Out:
# ['Asian | 629', 'Black | 618', 'White | 599', 'Other | 582', 'Hispanic | 572']

# %%
emp['StartDate'] = pd.to_datetime(emp['StartDate'], format='%d-%b-%y')

# %%
 emp[emp['StartDate'].dt.year > 2020]
# Out:
#       EmpID FirstName  LastName  StartDate   ExitDate  \
# 1      3428     Paula     Small 2023-02-11        NaN
# 3      3430   Michael   Riordan 2021-06-21        NaN
# 6      3433     Latia     Costa 2022-04-06  03-Jul-23
# 9      3436    Joseph   Martins 2022-01-21  29-Jun-23
# 10     3437    Myriam    Givens 2023-08-04        NaN
# ...     ...       ...       ...        ...        ...
# 2990   3417   Brayden     Singh 2022-02-07        NaN
# 2991   3418     Karma    Palmer 2022-10-14        NaN
# 2994   3421   Brenden     Leach 2022-05-09  08-Sep-22
# 2995   3422    Jakobe  Erickson 2022-06-22  07-Aug-22
# 2999   3426     Chace      Kerr 2022-04-27        NaN
#
#                         Title       Supervisor                        ADEmail  \
# 1     Production Technician I  Renee Mccormick      paula.small@bilearner.com
# 3          Area Sales Manager   Rebekah Wright  michael.riordan@bilearner.com
# 6          Area Sales Manager      Jacob Braun      latia.costa@bilearner.com
# ...

# %%
 emp[emp['StartDate'].dt.year > 2020]['StartDate'].count()

 # 1555 employees started after 2020
# Out:
# 1555
